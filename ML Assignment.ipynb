# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/goodreads-or-badreads/sample_submission.csv
# /kaggle/input/goodreads-or-badreads/train.csv
# /kaggle/input/goodreads-or-badreads/test.csv

# %%
import pandas as pd
import datetime as dt
df=pd.read_csv("/kaggle/input/goodreads-or-badreads/train.csv")
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  I "read" this as an audiobook. \n This book fo...
# 1  Easily one of the best sci-fi books out there ...
# 2  Best. Sarah. Dessen. Book. Ever. And to anyone...
# 3  This series just gets better and better, and S...
# 4  For reviews on all the hottest to the underhyp...
#
#                        date_added                    date_updated  \
# 0  Tue Sep 12 17:14:59 -0700 2017  Tue Sep 12 17:24:30 -0700 2017
# ...

# %%
from datetime import datetime

timestamp = "Tue Sep 12 17:14:59 -0700 2017"

# Convert string to datetime object
date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")

# Extract the day of the week
day_of_week = date_obj.strftime("%a")

print(day_of_week)
# Out:
# Tue

# %% [markdown]
# # Function to extract day of the week
# def extract_day_of_week(timestamp):
#     date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")
#     return date_obj.strftime("%a")
#
# # Apply the function to the 'start_date' column
# df['day_of_date_added'] = df['date_added'].apply(extract_day_of_week)
#
# df.head()
# # Function to extract day of the week
# def extract_day_of_week(timestamp):
#     date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")
#     return date_obj.strftime("%b")
#
# # Apply the function to the 'start_date' column
# df['month_of_date_added'] = df['date_added'].apply(extract_day_of_week)
#
# df.head()

# %%
# List of desired columns to extract day of the week
desired_columns = ['date_added','read_at','date_updated','started_at']

# Function to extract day of the week
def extract_day_of_week(timestamp):
    if pd.isnull(timestamp):  # Check for NaN values
        return None
    date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")
    return date_obj.strftime("%a")

# Apply the function to desired columns and create new columns
for column in desired_columns:
    df[f'{column}_day_of_week'] = df[column].apply(extract_day_of_week)
    
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  I "read" this as an audiobook. \n This book fo...
# 1  Easily one of the best sci-fi books out there ...
# 2  Best. Sarah. Dessen. Book. Ever. And to anyone...
# 3  This series just gets better and better, and S...
# 4  For reviews on all the hottest to the underhyp...
#
#                        date_added                    date_updated  \
# 0  Tue Sep 12 17:14:59 -0700 2017  Tue Sep 12 17:24:30 -0700 2017
# ...

# %%
# List of desired columns to  extract month
desired_columns = ['date_added','read_at','date_updated','started_at']

# Function to extract month
def extract_day_of_week(timestamp):
    if pd.isnull(timestamp):  # Check for NaN values
        return None
    date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")
    return date_obj.strftime("%b")

# Apply the function to desired columns and create new columns
for column in desired_columns:
    df[f'{column}_month'] = df[column].apply(extract_day_of_week)
    
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  I "read" this as an audiobook. \n This book fo...
# 1  Easily one of the best sci-fi books out there ...
# 2  Best. Sarah. Dessen. Book. Ever. And to anyone...
# 3  This series just gets better and better, and S...
# 4  For reviews on all the hottest to the underhyp...
#
#                        date_added                    date_updated  \
# 0  Tue Sep 12 17:14:59 -0700 2017  Tue Sep 12 17:24:30 -0700 2017
# ...

# %%
# List of desired columns to extract date
desired_columns = ['date_added','read_at','date_updated','started_at']

# Function to extract date
def extract_day_of_week(timestamp):
    if pd.isnull(timestamp):  # Check for NaN values
        return None
    date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")
    return date_obj.strftime("%d")

# Apply the function to desired columns and create new columns
for column in desired_columns:
    df[f'{column}_date'] = df[column].apply(extract_day_of_week)
    
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  I "read" this as an audiobook. \n This book fo...
# 1  Easily one of the best sci-fi books out there ...
# 2  Best. Sarah. Dessen. Book. Ever. And to anyone...
# 3  This series just gets better and better, and S...
# 4  For reviews on all the hottest to the underhyp...
#
#                        date_added                    date_updated  \
# 0  Tue Sep 12 17:14:59 -0700 2017  Tue Sep 12 17:24:30 -0700 2017
# ...

# %%
# List of desired columns to extract date
desired_columns = ['date_added','read_at','date_updated','started_at']

# Function to extract time
def extract_day_of_week(timestamp):
    if pd.isnull(timestamp):  # Check for NaN values
        return None
    date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")
    return date_obj.strftime("%H:%M:%S")

# Apply the function to desired columns and create new columns
for column in desired_columns:
    df[f'{column}_time'] = df[column].apply(extract_day_of_week)
    
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  I "read" this as an audiobook. \n This book fo...
# 1  Easily one of the best sci-fi books out there ...
# 2  Best. Sarah. Dessen. Book. Ever. And to anyone...
# 3  This series just gets better and better, and S...
# 4  For reviews on all the hottest to the underhyp...
#
#                        date_added                    date_updated  \
# 0  Tue Sep 12 17:14:59 -0700 2017  Tue Sep 12 17:24:30 -0700 2017
# ...

# %%
# List of desired columns to extract date
desired_columns = ['date_added','read_at','date_updated','started_at']

# Function to extract day of the week
def extract_day_of_week(timestamp):
    if pd.isnull(timestamp):  # Check for NaN values
        return None
    date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")
    return date_obj.strftime("%z")

# Apply the function to desired columns and create new columns
for column in desired_columns:
    df[f'{column}_zone'] = df[column].apply(extract_day_of_week)
    
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  I "read" this as an audiobook. \n This book fo...
# 1  Easily one of the best sci-fi books out there ...
# 2  Best. Sarah. Dessen. Book. Ever. And to anyone...
# 3  This series just gets better and better, and S...
# 4  For reviews on all the hottest to the underhyp...
#
#                        date_added                    date_updated  \
# 0  Tue Sep 12 17:14:59 -0700 2017  Tue Sep 12 17:24:30 -0700 2017
# ...

# %%
# List of desired columns to extract date
desired_columns = ['date_added','read_at','date_updated','started_at']

# Function to extract day of the week
def extract_day_of_week(timestamp):
    if pd.isnull(timestamp):  # Check for NaN values
        return None
    date_obj = datetime.strptime(timestamp, "%a %b %d %H:%M:%S %z %Y")
    return date_obj.strftime("%Y")

# Apply the function to desired columns and create new columns
for column in desired_columns:
    df[f'{column}_year'] = df[column].apply(extract_day_of_week)
    
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  I "read" this as an audiobook. \n This book fo...
# 1  Easily one of the best sci-fi books out there ...
# 2  Best. Sarah. Dessen. Book. Ever. And to anyone...
# 3  This series just gets better and better, and S...
# 4  For reviews on all the hottest to the underhyp...
#
#                        date_added                    date_updated  \
# 0  Tue Sep 12 17:14:59 -0700 2017  Tue Sep 12 17:24:30 -0700 2017
# ...

# %%
df.shape
df.columns
# Out:
# Index(['user_id', 'book_id', 'review_id', 'review_text', 'date_added',
#        'date_updated', 'read_at', 'started_at', 'n_votes', 'n_comments',
#        'rating', 'date_added_day_of_week', 'read_at_day_of_week',
#        'date_updated_day_of_week', 'started_at_day_of_week',
#        'date_added_month', 'read_at_month', 'date_updated_month',
#        'started_at_month', 'date_added_date', 'read_at_date',
#        'date_updated_date', 'started_at_date', 'date_added_time',
#        'read_at_time', 'date_updated_time', 'started_at_time',
#        'date_added_zone', 'read_at_zone', 'date_updated_zone',
#        'started_at_zone', 'date_added_year', 'read_at_year',
#        'date_updated_year', 'started_at_year'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# user_id                          0
# book_id                          0
# review_id                        0
# review_text                      0
# date_added                       0
# date_updated                     0
# read_at                      64225
# started_at                  192037
# n_votes                          0
# n_comments                       0
# rating                           0
# date_added_day_of_week           0
# read_at_day_of_week          64225
# date_updated_day_of_week         0
# started_at_day_of_week      192037
# date_added_month                 0
# read_at_month                64225
# date_updated_month               0
# started_at_month            192037
# date_added_date                  0
# read_at_date                 64225
# date_updated_date                0
# started_at_date             192037
# date_added_time                  0
# read_at_time                 64225
# date_updated_time                0
# started_at_time             192037
# ...

# %%
df.dtypes
# Out:
# user_id                     object
# book_id                      int64
# review_id                   object
# review_text                 object
# date_added                  object
# date_updated                object
# read_at                     object
# started_at                  object
# n_votes                      int64
# n_comments                   int64
# rating                       int64
# date_added_day_of_week      object
# read_at_day_of_week         object
# date_updated_day_of_week    object
# started_at_day_of_week      object
# date_added_month            object
# read_at_month               object
# date_updated_month          object
# started_at_month            object
# date_added_date             object
# read_at_date                object
# date_updated_date           object
# started_at_date             object
# date_added_time             object
# read_at_time                object
# date_updated_time           object
# started_at_time             object
# ...

# %%
import numpy as np
df['date_is_weekend']=np.where((df['date_added_day_of_week']).isin(['Sunday','Saturday']),1,0)
df['read_is_weekend']=np.where((df['read_at_day_of_week']).isin(['Sunday','Saturday']),1,0)
df['date_updated_is_weekend']=np.where((df['date_updated_day_of_week']).isin(['Sunday','Saturday']),1,0)
df['started_at_is_weekend']=np.where((df['started_at_day_of_week']).isin(['Sunday','Saturday']),1,0)
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  I "read" this as an audiobook. \n This book fo...
# 1  Easily one of the best sci-fi books out there ...
# 2  Best. Sarah. Dessen. Book. Ever. And to anyone...
# 3  This series just gets better and better, and S...
# 4  For reviews on all the hottest to the underhyp...
#
#                        date_added                    date_updated  \
# 0  Tue Sep 12 17:14:59 -0700 2017  Tue Sep 12 17:24:30 -0700 2017
# ...

# %%
object_columns = df.select_dtypes(include=['object']).columns
df[object_columns] = df[object_columns].apply(lambda x: x.str.lower())

# %%
df['review_text'][5533]
# Out:
# 'i\'ve spent most of a day off wondering what to say about a brief history of seven killings as i have mixed feelings about this book. but i am still exhausted from making it through this book, so i don\'t want to write my own novel about it either. i\'ve compiled a list of things i liked and another list of things that weren\'t my cup of tea. \n things that worked well: \n 1. the audiobook is awesome. it\'s more of a radio play than narration, as multiple voice actors tackle different chapters, which follows the shifting narration of the book. because i listened to the audiobook, none of the patois was difficult to understand and it made the characters seem very authentic. i highly recommend this audiobook, but not if you\'re listening in a group that includes kids, as there is tons of coarse language, violence, sex, you name it, so, headphones are a must. \n 2.the various plots are separately intriguing. then when there is interactions between these seemingly distinct universes (wo
# ...

# %%
import re
def remove(text):
    pattern=re.compile('\n')
    return pattern.sub(r'',text)
df['review_text']=df['review_text'].apply(remove)

# %%
df["review_text"] = df["review_text"].astype('str')
target_column = 'review_text'
df[target_column] = df[target_column].str.replace('\t', '', regex=False)

# Save the modified DataFrame back to a CSV file
df.to_csv('train.csv', index=False)

# %%
import string,time
string.punctuation
exclude=string.punctuation
def remove_punc(text):
    return text.translate(str.maketrans('','',exclude))
df['review_text']=df['review_text'].apply(remove_punc)

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
target_column = 'review_text'

# Set English stopwords from NLTK
stop_words = set(stopwords.words('english'))

# Function to remove stopwords
def remove_stopwords(text):
    text = ' '.join(word for word in text.split() if word.lower() not in stop_words)
    return text

# Remove stopwords from the specified column
df[target_column] = df[target_column].apply(remove_stopwords)

# Save the modified DataFrame back to a CSV file
df.to_csv('training.csv', index=False)
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.tokenize import word_tokenize

nltk.download('punkt')
target_column = 'review_text'
def tokenize(text):
    return word_tokenize(text)
df[target_column + '_tokens'] = df[target_column].apply(tokenize)

# Save the modified DataFrame back to CSV file
df.to_csv('training.csv', index=False)
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['review_text_tokens'][0]
# Out:
# ['read',
#  'audiobook',
#  'book',
#  'follows',
#  'primarily',
#  'jack',
#  'private',
#  'detective',
#  'private',
#  'get',
#  'several',
#  'characters',
#  'including',
#  'twin',
#  'brother',
#  'multiple',
#  'love',
#  'interests',
#  'suspects',
#  'coworkers',
#  'light',
#  'read',
#  'mean',
#  'wasnt',
#  'horrible',
#  'couldnt',
#  'finish',
#  'listening',
#  'guess',
#  'liked',
#  'ok',
#  'multiple',
#  'plot',
#  'lines',
#  'dont',
#  'relate',
#  'way',
#  'lots',
#  'super',
#  'cheesy',
#  'dialogue',
#  'despite',
#  'couple',
#  'mildly',
#  'interesting',
#  'subplots',
#  'real',
#  'suspense',
#  'pick',
#  'book',
#  'want',
#  'quickish',
#  'read',
#  'dont',
#  'invest',
#  'lot',
#  'brainpower']

# %%
from nltk.stem.porter import PorterStemmer

stemmer = PorterStemmer()
def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

df["text_stemmed"] = df["review_text"].apply(lambda text: stem_words(text))
df.head()
# Out:
#                             user_id   book_id  \
# 0  5845f85c23e768f0636c9c7f77f3a529   7134202
# 1  4251532f32b7e8b98912188f4d962eb1   2767052
# 2  2cabd95f62285fc08f4c544afaee5ea4   8492856
# 3  2d61d345434328a188f805ec75dde2c2  13206760
# 4  a3e696e6ced8daae338eccf12ac58053   7171637
#
#                           review_id  \
# 0  55d9037adc00645b17f0cf43fa4d053e
# 1  e5f389a112b12d560e42e0c5c3d4eb35
# 2  e7892549ac69653aceaac86760575aa0
# 3  ab4acc9ad0a24a072356c331880b83d5
# 4  0b65c86a90814e4ab5db50e0cd3dc808
#
#                                          review_text  \
# 0  read audiobook book follows primarily jack pri...
# 1  easily one best scifi books kids didnt think s...
# 2  best sarah dessen book ever anyone says book s...
# 3  series gets better better scarlet didnt disapp...
# 4  reviews hottest underhyped books ya lit enter ...
#
#                        date_added                    date_updated  \
# 0  tue sep 12 17:14:59 -0700 2017  tue sep 12 17:24:30 -0700 2017
# ...

# %%
df['text_stemmed'][0]
# Out:
# 'read audiobook book follow primarili jack privat detect privat get sever charact includ twin brother multipl love interest suspect cowork light read mean wasnt horribl couldnt finish listen guess like ok multipl plot line dont relat way lot super cheesi dialogu despit coupl mildli interest subplot real suspens pick book want quickish read dont invest lot brainpow'
